# %%
import numpy as np

# %%
import crawler as cr

#download score records to database

username = 'root'
password = 'bgzwosdfz0617..'
host = 'localhost:3306'
dbname = 'nctta_rating_1'

url = "http://danserver.com/nctta/IndivMatches.asp?id="
crawler = cr.Craweling(url,13870)
DBC = DatabaseConnect(username, password, host, dbname)

# %%
DBC.write_crawler(crawler,'score_history')
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 1065
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 1068
# 1100
# 1200
# 1300
# 1400
# 1500
# TypeErrror: invalid literal for int() with base 10: ''
# 1547
# 1600
# TypeErrror: invalid literal for int() with base 10: ''
# 1634
# 1700
# TypeErrror: invalid literal for int() with base 10: ''
# 1711
# 1800
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 1815
# TypeErrror: HTTPConnectionPool(host='danserver.com', port=80): Max retries exceeded with url: /nctta/IndivMatches.asp?id=1852 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013EABE28780>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# 1852
# 1900
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 1925
# TypeErrror: invalid literal for int() with base 10: ''
# 1963
# 2000
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2007
# TypeErrror: HTTPConnectionPool(host='danserver.com', port=80): Max retries exceeded with url: /nctta/IndivMatches.asp?id=2059 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013EABC0FB70>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# 2059
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2072
# 2100
# 2200
# 2300
# 2400
# TypeErrror: invalid literal for int() with base 10: ''
# 2428
# TypeErrror: HTTPConnectionPool(host='danserver.com', port=80): Max retries exceeded with url: /nctta/IndivMatches.asp?id=2439 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013EABCCC128>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# 2439
# 2500
# 2600
# TypeErrror: invalid literal for int() with base 10: ''
# 2673
# 2700
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2795
# 2800
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2831
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 2832
# 2900
# 3000
# 3100
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3136
# 3200
# 3300
# connection error
# 3400
# TypeErrror: operands could not be broadcast together with shapes (66,) (65,)
# 3415
# TypeErrror: operands could not be broadcast together with shapes (64,) (63,)
# 3417
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3444
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3445
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3450
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3453
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3454
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3456
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3461
# 3500
# 3600
# 3700
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3742
# 3800
# TypeErrror: HTTPConnectionPool(host='danserver.com', port=80): Max retries exceeded with url: /nctta/IndivMatches.asp?id=3869 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000013EABE60240>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
# 3869
# 3900
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3926
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 3958
# 4000
# 4100
# TypeErrror: operands could not be broadcast together with shapes (77,) (76,)
# 4178
# TypeErrror: operands could not be broadcast together with shapes (32,) (31,)
# 4184
# 4200
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 4281
# 4300
# 4400
# 4500
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 4511
# 4600
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 4697
# 4700
# 4800
# 4900
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 4900
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 4901
# TypeErrror: operands could not be broadcast together with shapes (16,) (14,)
# 4985
# TypeErrror: operands could not be broadcast together with shapes (24,) (22,)
# 4987
# TypeErrror: operands could not be broadcast together with shapes (37,) (34,)
# 4988
# TypeErrror: operands could not be broadcast together with shapes (9,) (8,)
# 4994
# 5000
# TypeErrror: operands could not be broadcast together with shapes (114,) (112,)
# 5008
# TypeErrror: operands could not be broadcast together with shapes (35,) (34,)
# 5030
# 5100
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 5179
# 5200
# TypeErrror: list assignment index out of range
# 5209
# 5300
# 5400
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 5406
# 5500
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 5510
# 5600
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 5697
# 5700
# 5800
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 5800
# TypeErrror: list assignment index out of range
# 5854
# 5900
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10305
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10319
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10344
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10345
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10359
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10373
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10383
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10385
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10387
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10393
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10398
# 10400
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10402
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10404
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10432
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10439
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10456
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10460
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10463
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10479
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10494
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10499
# 10500
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10500
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10501
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10502
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10503
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10512
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10513
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10514
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10517
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10549
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10552
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10564
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10572
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10579
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10580
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10581
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10582
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10583
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10586
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10596
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10597
# 10600
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10607
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10634
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10666
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10668
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10670
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10674
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10675
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10694
# 10700
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10731
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10732
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10741
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10755
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10781
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 10788
# ...
# 13260
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13270
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13274
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13275
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13283
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13288
# 13300
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13308
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13317
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13324
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13337
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13368
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13370
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13377
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13378
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13379
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13387
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13393
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13397
# 13400
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13402
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13407
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13417
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13420
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13432
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13433
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13448
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13449
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13472
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13473
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13474
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13475
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13476
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13477
# 13500
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13503
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13512
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13523
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13528
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13540
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13563
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13564
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13572
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13577
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13594
# 13600
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13624
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13625
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13626
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13627
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13628
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13633
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13638
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13646
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13666
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13674
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13675
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13676
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13678
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13693
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13696
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13697
# 13700
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13704
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13705
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13715
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13716
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13722
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13723
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13724
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13731
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13738
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13742
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13746
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13750
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13754
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13757
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13768
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13769
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13771
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13777
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13781
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13784
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13786
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13787
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13788
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13789
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13790
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13797
# 13800
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13809
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13817
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13818
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13832
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13846
# TypeErrror: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# 13859

# %%
result = DBC.read('Select * from score_history')
player_id = np.unique(result['Loser_id'].append(result['Winner_id']))

# %%
url1 = "http://danserver.com/nctta/PlayerRatingHistory.aspx?PlayerId="
player_c = Craweling_athlete(url1, player_id)

# %%
url2 = "http://danserver.com/nctta/Players.asp?id="
player_r = cr.CrawelingCurrentRating(url2, player_id)

# %%
player_id
# Out:
# array([   11,    17,    18, ..., 13937, 13938, 13939], dtype=int64)

# %%
dict_list = []
for i in player_id:
    if i % 100 == 0:
        print(i)
    try:
        dictionary = player_r.getpageitem(i)
        dict_list.append(dictionary)
    except Exception as e:
        print('TypeErrror:', e)
        print(i)
    time.sleep(0.1+0.5*random.random())
# Out:
# 200
# 500
# 700
# 800
# 900
# 1000
# 1100
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2400
# 2500
# 2700
# 2800
# 2900
# 3000
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 3950
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4800
# 5000
# 5100
# 5300
# 5400
# 5500
# 5600
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 5687
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7900
# 8000
# 8100
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9300
# 9500
# 9800
# 9900
# 10100
# 10200
# 10300
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 10369
# 10400
# 10600
# 10700
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 10797
# 10900
# 11100
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12200
# 12300
# 12400
# 12500
# 12600
# 12900
# 13000
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800

# %%
dd = []
for i in dict_list:
    if i:
        dd.append(i)

# %%
pd.DataFrame.from_records(dd).to_csv('current_rating.csv')

# %%
player_id
# Out:
# array([   11,    17,    18, ..., 13937, 13938, 13939], dtype=int64)

# %%
len(player_id)
# Out:
# 11209

# %%
DBC.write_crawler(player_r, 'current_rating')
# Out:
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 5
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 40
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 86
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 95
# 100
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 123
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 127
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 175
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 180
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 188
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 189
# 200
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 215
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 218
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 221
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 238
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 274
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 275
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 297
# 300
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 352
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 378
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 393
# 400
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 401
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 408
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 409
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 410
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 411
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 422
# TypeErrror: 'NoneType' object has no attribute 'next_element'
# 424
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9cded267a47f> in <module>()
# ----> 1 DBC.write_crawler(player_r, 'current_rating')
#
# <ipython-input-5-db1196a2f044> in write_crawler(self, crawler, table)
#      28                 print('TypeErrror:', e)
#      29                 print(i)
# ---> 30             time.sleep(0.1+0.5*random.random())
#
# KeyboardInterrupt:

# %%
from sqlalchemy import create_engine
import pandas as pd
import time 
import random

class DatabaseConnect(object):

    def __init__(self, username, password, host, dbname):
        self.DB_CON_STR = 'mysql+pymysql://' + username + ':' \
                          + password + '@' + host + '/' + dbname + '?charset=utf8'
        self.engine = create_engine(self.DB_CON_STR, echo=False)

    def read(self, sql):
        return pd.read_sql(sql, con=self.engine)

    def write(self, df, table):
        if type(df) != bool:
            df.to_sql(table, self.engine, if_exists='append')

    def write_crawler(self, crawler, table):
        id_list = range(1, 13870)
        for i in id_list:
            if i % 100 == 0:
                print(i)
            try:
                df = crawler.getpageitem(i)
                self.write(df, table)
            except Exception as e:
                print('TypeErrror:', e)
                print(i)
            time.sleep(0.1+0.5*random.random())
